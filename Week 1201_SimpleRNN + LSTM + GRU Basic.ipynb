# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences

MaxFeatures = 10000
MaxLen = 100

(train_input, train_target), (test_input, test_target) = imdb.load_data(num_words=MaxFeatures)

train_input = pad_sequences(train_input, maxlen=MaxLen)
test_input = pad_sequences(test_input, maxlen=MaxLen)

print(train_input.shape, train_target.shape)
print(test_input.shape, test_target.shape)
# Out:
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/datasets/imdb.py:155: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/datasets/imdb.py:156: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])
# (25000, 100) (25000,)
# (25000, 100) (25000,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, SimpleRNN, LSTM, GRU

# %% [markdown]
# # SimpleRNN

# %%
model = Sequential()

model.add(Embedding(
    input_dim=MaxFeatures,
    output_dim=32,
    input_length=MaxLen
))
model.add(SimpleRNN(
    units=32,
    return_sequences=False
))
model.add(Dense(1, activation='sigmoid'))

model.compile(
    optimizer='rmsprop',
    loss='binary_crossentropy',
    metrics=['acc']
)

history = model.fit(
    train_input,
    train_target,
    epochs=10,
    batch_size=128,
    validation_split=0.2
)
# Out:
# Epoch 1/10
# 157/157 [==============================] - 18s 89ms/step - loss: 0.6546 - acc: 0.5941 - val_loss: 0.5241 - val_acc: 0.7530
# Epoch 2/10
# 157/157 [==============================] - 13s 86ms/step - loss: 0.3935 - acc: 0.8317 - val_loss: 0.4812 - val_acc: 0.7590
# Epoch 3/10
# 157/157 [==============================] - 14s 90ms/step - loss: 0.2731 - acc: 0.8924 - val_loss: 0.4025 - val_acc: 0.8408
# Epoch 4/10
# 157/157 [==============================] - 15s 96ms/step - loss: 0.1902 - acc: 0.9282 - val_loss: 0.4224 - val_acc: 0.8456
# Epoch 5/10
# 157/157 [==============================] - 15s 93ms/step - loss: 0.1199 - acc: 0.9592 - val_loss: 0.4896 - val_acc: 0.8216
# Epoch 6/10
# 157/157 [==============================] - 14s 89ms/step - loss: 0.0686 - acc: 0.9803 - val_loss: 0.6133 - val_acc: 0.8188
# Epoch 7/10
# 157/157 [==============================] - 14s 89ms/step - loss: 0.0395 - acc: 0.9883 - val_loss: 0.5885 - val_acc: 0.8258
# Epoch 8/10
# 157/157 [==============================] - 15s 95ms/step - loss: 0.0251 - acc: 0.9937 - val_loss: 0.7076 - val_acc: 0.8066
# Epoch 9/10
# 157/157 [==============================] - 15s 97ms/step - loss: 0.0162 - acc: 0.9957 - val_loss: 0.6918 - val_acc: 0.8188
# Epoch 10/10
# 157/157 [==============================] - 14s 91ms/step - loss: 0.0097 - acc: 0.9978 - val_loss: 0.7821 - val_acc: 0.7910

# %% [markdown]
# # LSTM

# %%
model = Sequential()

model.add(Embedding(
    input_dim=MaxFeatures + 1,
    output_dim=32,
    input_length=MaxLen
))
model.add(LSTM(
    units=32,
    return_sequences=True
))
model.add(Dense(1, activation='sigmoid'))

model.compile(
    optimizer='rmsprop',
    loss='binary_crossentropy',
    metrics=['acc']
)

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 100, 32)           320032
# _________________________________________________________________
# lstm (LSTM)                  (None, 100, 32)           8320
# _________________________________________________________________
# dense_1 (Dense)              (None, 100, 1)            33
# =================================================================
# Total params: 328,385
# Trainable params: 328,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    train_input,
    train_target,
    epochs=10,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/10
# 625/625 [==============================] - 11s 9ms/step - loss: 0.5466 - acc: 0.7106 - val_loss: 0.4963 - val_acc: 0.7485
# Epoch 2/10
# 625/625 [==============================] - 5s 8ms/step - loss: 0.4548 - acc: 0.7780 - val_loss: 0.4976 - val_acc: 0.7531
# Epoch 3/10
# 625/625 [==============================] - 5s 8ms/step - loss: 0.4287 - acc: 0.7938 - val_loss: 0.4964 - val_acc: 0.7550
# Epoch 4/10
# 625/625 [==============================] - 5s 8ms/step - loss: 0.4142 - acc: 0.8014 - val_loss: 0.4902 - val_acc: 0.7540
# Epoch 5/10
# 625/625 [==============================] - 5s 8ms/step - loss: 0.4030 - acc: 0.8089 - val_loss: 0.4981 - val_acc: 0.7520
# Epoch 6/10
# 625/625 [==============================] - 5s 8ms/step - loss: 0.3952 - acc: 0.8134 - val_loss: 0.5053 - val_acc: 0.7506
# Epoch 7/10
# 625/625 [==============================] - 5s 8ms/step - loss: 0.3879 - acc: 0.8165 - val_loss: 0.5368 - val_acc: 0.7502
# Epoch 8/10
# 625/625 [==============================] - 5s 8ms/step - loss: 0.3822 - acc: 0.8200 - val_loss: 0.5555 - val_acc: 0.7399
# Epoch 9/10
# 625/625 [==============================] - 5s 8ms/step - loss: 0.3748 - acc: 0.8234 - val_loss: 0.5020 - val_acc: 0.7516
# Epoch 10/10
# 625/625 [==============================] - 5s 8ms/step - loss: 0.3665 - acc: 0.8275 - val_loss: 0.4990 - val_acc: 0.7500

# %% [markdown]
# # GRU

# %%
model = Sequential()

model.add(Embedding(
    input_dim=MaxFeatures + 1,
    output_dim=32,
    input_length=MaxLen
))
model.add(GRU(
    units=32,
    return_sequences=True
))
model.add(Dense(1, activation='sigmoid'))

model.compile(
    optimizer='rmsprop',
    loss='binary_crossentropy',
    metrics=['acc']
)

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 100, 32)           320032
# _________________________________________________________________
# gru (GRU)                    (None, 100, 32)           6336
# _________________________________________________________________
# dense_2 (Dense)              (None, 100, 1)            33
# =================================================================
# Total params: 326,401
# Trainable params: 326,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    train_input,
    train_target,
    epochs=10,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/10
# 625/625 [==============================] - 7s 9ms/step - loss: 0.5430 - acc: 0.7106 - val_loss: 0.4926 - val_acc: 0.7496
# Epoch 2/10
# 625/625 [==============================] - 5s 8ms/step - loss: 0.4552 - acc: 0.7774 - val_loss: 0.5108 - val_acc: 0.7454
# Epoch 3/10
# 625/625 [==============================] - 5s 8ms/step - loss: 0.4286 - acc: 0.7925 - val_loss: 0.4885 - val_acc: 0.7548
# Epoch 4/10
# 625/625 [==============================] - 5s 8ms/step - loss: 0.4138 - acc: 0.8017 - val_loss: 0.4897 - val_acc: 0.7547
# Epoch 5/10
# 625/625 [==============================] - 5s 8ms/step - loss: 0.4037 - acc: 0.8075 - val_loss: 0.4895 - val_acc: 0.7524
# Epoch 6/10
# 625/625 [==============================] - 5s 8ms/step - loss: 0.3946 - acc: 0.8125 - val_loss: 0.5327 - val_acc: 0.7437
# Epoch 7/10
# 625/625 [==============================] - 5s 7ms/step - loss: 0.3874 - acc: 0.8163 - val_loss: 0.5110 - val_acc: 0.7467
# Epoch 8/10
# 625/625 [==============================] - 5s 8ms/step - loss: 0.3793 - acc: 0.8207 - val_loss: 0.5206 - val_acc: 0.7534
# Epoch 9/10
# 625/625 [==============================] - 5s 8ms/step - loss: 0.3712 - acc: 0.8253 - val_loss: 0.5074 - val_acc: 0.7533
# Epoch 10/10
# 625/625 [==============================] - 5s 7ms/step - loss: 0.3623 - acc: 0.8300 - val_loss: 0.4984 - val_acc: 0.7544
