# %% [markdown]
# # 1. Data Cleaning

# %%
import pandas as pd
import numpy as np
np.random.seed(123)

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('Midterm Exam/data/train.csv')
df.head()
# Out:
#         id  target  car_01_cat  car_02_cat  car_03_cat  car_04_cat    car_05  \
# 0  C000000       0           4          -1           0          12  3.316625
# 1  C000001       0           0           1           0          39  2.449490
# 2  C000002       0           0          -1           2         100  3.464102
# 3  C000003       0           9           1           0          93  3.741657
# 4  C000004       0           0           0           1         104  3.741657
#
#      car_06  car_07_cat  car_08_cat  ...  idx_14  idx_15_bin  idx_16_bin  \
# 0  0.370810           1           1  ...       7           0           0
# 1  0.374433           1           1  ...      11           0           1
# 2  0.423084           1           1  ...      11           0           0
# 3  0.316228           0           0  ...       7           0           0
# 4  0.430116           1           0  ...       6           0           0
#
#    idx_17  idx_18  idx_19  idx_20  loc_01  loc_02    loc_03
# 0       0       3       7       1     0.6     0.7  0.878564
# 1       0       6       8       1     0.6     0.6  0.981708
# 2       0       1       8       3     0.2     0.9  0.495606
# 3       3       3       8       4     1.8     0.9  2.066549
# 4       1       1       7       4     0.0     0.4  0.740355
#
# [5 rows x 59 columns]

# %% [markdown]
# ## Delete Meaningless Columns

# %%
df = df.drop('id', axis=1)
df.head()
# Out:
#    target  car_01_cat  car_02_cat  car_03_cat  car_04_cat    car_05    car_06  \
# 0       0           4          -1           0          12  3.316625  0.370810
# 1       0           0           1           0          39  2.449490  0.374433
# 2       0           0          -1           2         100  3.464102  0.423084
# 3       0           9           1           0          93  3.741657  0.316228
# 4       0           0           0           1         104  3.741657  0.430116
#
#    car_07_cat  car_08_cat    car_09  ...  idx_14  idx_15_bin  idx_16_bin  \
# 0           1           1  0.754792  ...       7           0           0
# 1           1           1  0.614780  ...      11           0           1
# 2           1           1  0.815665  ...      11           0           0
# 3           0           0  1.068114  ...       7           0           0
# 4           1           0  1.509768  ...       6           0           0
#
#    idx_17  idx_18  idx_19  idx_20  loc_01  loc_02    loc_03
# 0       0       3       7       1     0.6     0.7  0.878564
# 1       0       6       8       1     0.6     0.6  0.981708
# 2       0       1       8       3     0.2     0.9  0.495606
# 3       3       3       8       4     1.8     0.9  2.066549
# 4       1       1       7       4     0.0     0.4  0.740355
#
# [5 rows x 58 columns]

# %% [markdown]
# ## Split into INPUT and TARGET variables

# %%
df_target = df['target']
df_input = df.drop('target', axis=1)

# %% [markdown]
# ## Split into TRAIN and TEST sets

# %%
from sklearn.model_selection import train_test_split

train_input, test_input, train_target, test_target = train_test_split(df_input, df_target,
                                                                     test_size=0.3,
                                                                     stratify=df_target)

# %% [markdown]
# ## Data Regularization: Min-Max Scaler

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(train_input)

train_input = scaler.transform(train_input)
test_input = scaler.transform(test_input)

# %% [markdown]
# # 2. Modeling

# %% [markdown]
# ## Model Definition

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.metrics import AUC

model = Sequential()

model.add(Dense(8, activation='relu', input_shape=(train_input.shape[1], )))
model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc', AUC()])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 8)                 464
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 36
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 505
# Trainable params: 505
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Model Fitting

# %%
model.fit(train_input, train_target, epochs=20, batch_size=32,
         validation_data=(test_input, test_target))
# Out:
# Epoch 1/20
# 9116/9116 [==============================] - 14s 1ms/step - loss: 0.1719 - acc: 0.9635 - auc: 0.5328 - val_loss: 0.1554 - val_acc: 0.9635 - val_auc: 0.5814
# Epoch 2/20
# 9116/9116 [==============================] - 11s 1ms/step - loss: 0.1558 - acc: 0.9635 - auc: 0.5757 - val_loss: 0.1572 - val_acc: 0.9635 - val_auc: 0.5815
# Epoch 3/20
# 9116/9116 [==============================] - 10s 1ms/step - loss: 0.1574 - acc: 0.9629 - auc: 0.5823 - val_loss: 0.1554 - val_acc: 0.9635 - val_auc: 0.5824
# Epoch 4/20
# 9116/9116 [==============================] - 10s 1ms/step - loss: 0.1541 - acc: 0.9639 - auc: 0.5816 - val_loss: 0.1561 - val_acc: 0.9635 - val_auc: 0.5829
# Epoch 5/20
# 9116/9116 [==============================] - 11s 1ms/step - loss: 0.1535 - acc: 0.9641 - auc: 0.5812 - val_loss: 0.1553 - val_acc: 0.9635 - val_auc: 0.5841
# Epoch 6/20
# 9116/9116 [==============================] - 11s 1ms/step - loss: 0.1548 - acc: 0.9637 - auc: 0.5846 - val_loss: 0.1556 - val_acc: 0.9635 - val_auc: 0.5834
# Epoch 7/20
# 9116/9116 [==============================] - 11s 1ms/step - loss: 0.1542 - acc: 0.9639 - auc: 0.5784 - val_loss: 0.1553 - val_acc: 0.9635 - val_auc: 0.5873
# Epoch 8/20
# 9116/9116 [==============================] - 11s 1ms/step - loss: 0.1546 - acc: 0.9637 - auc: 0.5858 - val_loss: 0.1564 - val_acc: 0.9635 - val_auc: 0.5840
# Epoch 9/20
# 9116/9116 [==============================] - 11s 1ms/step - loss: 0.1561 - acc: 0.9633 - auc: 0.5832 - val_loss: 0.1553 - val_acc: 0.9635 - val_auc: 0.5865
# Epoch 10/20
# 9116/9116 [==============================] - 11s 1ms/step - loss: 0.1554 - acc: 0.9636 - auc: 0.5774 - val_loss: 0.1553 - val_acc: 0.9635 - val_auc: 0.5877
# Epoch 11/20
# 9116/9116 [==============================] - 11s 1ms/step - loss: 0.1548 - acc: 0.9637 - auc: 0.5865 - val_loss: 0.1555 - val_acc: 0.9635 - val_auc: 0.5862
# Epoch 12/20
# 9116/9116 [==============================] - 11s 1ms/step - loss: 0.1564 - acc: 0.9633 - auc: 0.5765 - val_loss: 0.1550 - val_acc: 0.9635 - val_auc: 0.5890
# Epoch 13/20
# 9116/9116 [==============================] - 15s 2ms/step - loss: 0.1570 - acc: 0.9630 - auc: 0.5799 - val_loss: 0.1554 - val_acc: 0.9635 - val_auc: 0.5907
# Epoch 14/20
# 9116/9116 [==============================] - 11s 1ms/step - loss: 0.1539 - acc: 0.9640 - auc: 0.5823 - val_loss: 0.1551 - val_acc: 0.9635 - val_auc: 0.5898
# Epoch 15/20
# 9116/9116 [==============================] - 11s 1ms/step - loss: 0.1578 - acc: 0.9628 - auc: 0.5883 - val_loss: 0.1549 - val_acc: 0.9635 - val_auc: 0.5885
# Epoch 16/20
# 9116/9116 [==============================] - 18s 2ms/step - loss: 0.1577 - acc: 0.9628 - auc: 0.5822 - val_loss: 0.1551 - val_acc: 0.9635 - val_auc: 0.5902
# Epoch 17/20
# 9116/9116 [==============================] - 14s 2ms/step - loss: 0.1555 - acc: 0.9635 - auc: 0.5820 - val_loss: 0.1561 - val_acc: 0.9635 - val_auc: 0.5888
# Epoch 18/20
# 9116/9116 [==============================] - 17s 2ms/step - loss: 0.1567 - acc: 0.9631 - auc: 0.5814 - val_loss: 0.1552 - val_acc: 0.9635 - val_auc: 0.5904
# Epoch 19/20
# 9116/9116 [==============================] - 13s 1ms/step - loss: 0.1541 - acc: 0.9640 - auc: 0.5787 - val_loss: 0.1549 - val_acc: 0.9635 - val_auc: 0.5906
# Epoch 20/20
# 9116/9116 [==============================] - 11s 1ms/step - loss: 0.1549 - acc: 0.9637 - auc: 0.5813 - val_loss: 0.1551 - val_acc: 0.9635 - val_auc: 0.5893

# %% [markdown]
# # 3. Model Evaluations

# %% [markdown]
# ## Test Sample Loading and Evaluating

# %%
df_test = pd.read_csv('Midterm Exam/data/test_sample.csv')

df_test = df_test.drop('id', axis=1)

df_test_target = df_test['target']
df_test_input = df_test.drop('target', axis=1)
df_test_input.head()
# Out:
#    car_01_cat  car_02_cat  car_03_cat  car_04_cat    car_05    car_06  \
# 0           0           1           0          22  3.464102  0.310322
# 1           1           0           0          31  3.162278  0.385487
# 2          11          -1           0           7  2.236068  0.412916
# 3           0          -1           0          22  3.605551  0.374566
# 4           3           1           8         104  3.464102  0.539444
#
#    car_07_cat  car_08_cat    car_09  car_10  ...  idx_14  idx_15_bin  \
# 0           1           1  0.776608       3  ...      11           0
# 1           1           1  0.773609       3  ...       9           0
# 2           1           1  0.683271       3  ...      11           0
# 3           1           1  0.783481       3  ...      10           0
# 4           1           1  1.280802       2  ...       9           0
#
#    idx_16_bin  idx_17  idx_18  idx_19  idx_20  loc_01  loc_02    loc_03
# 0           0       1       1       9       3     0.3     0.7  0.917878
# 1           1       0       3       4       1     1.4     0.8  1.387894
# 2           0       2       2      12       5     0.2     0.6  0.562917
# 3           0       0       2       6       4     0.1     0.9  0.406202
# 4           0       3       2       7       3     0.0     0.3  0.784219
#
# [5 rows x 57 columns]

# %%
df_test_input = scaler.transform(df_test_input)

# %%
pd.DataFrame(df_test_input).describe().T
# Out:
#       count      mean       std       min       25%       50%       75%  \
# 0   35700.0  0.387937  0.323792  0.000000  0.058824  0.411765  0.647059
# 1   35700.0  0.422801  0.422409  0.000000  0.000000  0.500000  1.000000
# 2   35700.0  0.081967  0.242369  0.000000  0.000000  0.000000  0.000000
# 3   35700.0  0.596229  0.319499  0.000000  0.300971  0.621359  0.893204
# 4   35700.0  0.819094  0.195691  0.000000  0.755929  0.886405  0.963624
# 5   35700.0  0.779737  0.218867  0.000000  0.814238  0.836461  0.853852
# 6   35700.0  0.915560  0.187325  0.500000  1.000000  1.000000  1.000000
# 7   35700.0  0.830644  0.375071  0.000000  1.000000  1.000000  1.000000
# 8   35700.0  0.162352  0.065099  0.023456  0.121113  0.148577  0.188771
# 9   35700.0  0.837374  0.207699  0.250000  0.750000  1.000000  1.000000
# 10  35700.0  0.240479  0.049896  0.000000  0.185617  0.235353  0.257530
# 11  35700.0  0.466101  0.195594  0.000000  0.200000  0.600000  0.600000
# 53  35700.0  0.334774  0.157343  0.000000  0.222222  0.333333  0.444444
# 54  35700.0  0.244364  0.224813  0.000000  0.111111  0.166667  0.333333
# 55  35700.0  0.678715  0.319121  0.000000  0.444444  0.777778  1.000000
# 56  35700.0  0.308282  0.157424  0.000000  0.302821  0.342230  0.397607
#
#          max
# 0   1.000000
# 1   1.000000
# 2   1.000000
# 3   1.000000
# 4   1.000000
# 5   0.972630
# 6   1.000000
# 7   1.000000
# 8   0.848599
# 9   1.000000
# 10  1.000000
# 11  1.000000
# 12  1.000000
# 13  1.000000
# 14  1.000000
# 15  1.000000
# 16  1.000000
# 17  1.000000
# 18  1.000000
# 19  1.000000
# 20  0.750000
# 21  1.000000
# 22  1.000000
# 23  1.000000
# 24  1.000000
# 25  1.000000
# 26  1.000000
# 27  1.000000
# 28  1.000000
# 29  1.000000
# 30  1.000000
# 31  1.000000
# 32  1.000000
# 33  1.000000
# 34  1.000000
# 35  1.000000
# 36  1.000000
# 37  1.000000
# 38  1.000000
# 39  1.000000
# 40  1.000000
# 41  0.954545
# 42  1.000000
# 43  1.000000
# 44  1.000000
# 45  1.000000
# 46  1.000000
# 47  1.000000
# 48  1.000000
# 49  1.000000
# 50  1.000000
# 51  0.923077
# 52  0.958333
# 53  1.000000
# 54  1.000000
# 55  1.000000
# 56  0.891394

# %% [markdown]
# ## Prediction and Evaluation

# %%
from sklearn.metrics import roc_auc_score

pred = model.predict(df_test_input)
pred
# Out:
# array([[0.0475443 ],
#        [0.0405857 ],
#        [0.03791597],
#        ...,
#        [0.04487786],
#        [0.04613823],
#        [0.03584486]], dtype=float32)

# %%
roc_auc_score(df_test_target, pred)
# Out:
# 0.5951047294275492

# %% [markdown]
# ## Test Total Loading and Evaluating

# %%
df_test_total = pd.read_csv('Midterm Exam/data/test_full.csv')
df_test_total.head()
# Out:
#         id  car_01_cat  car_02_cat  car_03_cat  car_04_cat    car_05  \
# 0  T000000          11           0           0          53  3.162278
# 1  T000001           0           0           0          39  2.828427
# 2  T000002           0           0           0          22  3.316625
# 3  T000003          11          -1           0         104  0.000000
# 4  T000004           0           0           0          78  3.741657
#
#      car_06  car_07_cat  car_08_cat    car_09  ...  idx_14  idx_15_bin  \
# 0  0.357071           1           1  0.824621  ...      11           1
# 1 -1.000000           1           1  0.660922  ...      11           0
# 2  0.374566           1           1  0.752269  ...       8           0
# 3  0.378814           1           1  0.470273  ...       9           1
# 4  0.328786           1           0  0.895316  ...       9           0
#
#    idx_16_bin  idx_17  idx_18  idx_19  idx_20  loc_01  loc_02    loc_03
# 0           0       0       4       6       2     0.7     0.9  1.147279
# 1           0       2       3       6       3     0.2     0.5  0.670820
# 2           0       3       4       3       3     0.9     0.9  1.477117
# 3           0       2       2       8       2     0.0     0.0  0.571183
# 4           0       1       2       6       3     0.3     0.9  0.757050
#
# [5 rows x 58 columns]

# %%
df_test_total_input = df_test_total.drop('id', axis=1)
df_test_total_input = scaler.transform(df_test_total_input)

pred = model.predict(df_test_total_input)
pred
# Out:
# array([[0.03700715],
#        [0.03806365],
#        [0.02600452],
#        ...,
#        [0.01717088],
#        [0.03483874],
#        [0.03789285]], dtype=float32)
